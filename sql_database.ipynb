# %% [markdown]
# <a href="https://colab.research.google.com/github/Asaf1h/university-database/blob/main/sql_database.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install Faker

import sqlite3
from faker import Faker
import numpy as np
import os
from prettytable import PrettyTable
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: Faker in /usr/local/lib/python3.10/dist-packages (18.11.1)
# Requirement already satisfied: python-dateutil>=2.4 in /usr/local/lib/python3.10/dist-packages (from Faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.4->Faker) (1.16.0)

# %%
def update_course_students_count(conn):
    # Connect to the SQLite database
    cursor = conn.cursor()

    # Check if the StudentsCount column exists in the Courses table
    cursor.execute("PRAGMA table_info(Courses)")
    columns = cursor.fetchall()
    students_count_exists = any(column[1] == 'StudentsCount' for column in columns)

    if students_count_exists:
        # Update the StudentsCount column with the sum of students for each course
        cursor.execute('UPDATE Courses SET StudentsCount = (SELECT COUNT(*) FROM Students WHERE Students.CourseID_1 = Courses.CourseID OR Students.CourseID_2 = Courses.CourseID OR Students.CourseID_3 = Courses.CourseID OR Students.CourseID_4 = Courses.CourseID)')
    else:
        # Add the StudentsCount column to the Courses table
        cursor.execute('ALTER TABLE Courses ADD COLUMN StudentsCount INTEGER DEFAULT 0')
        cursor.execute('UPDATE Courses SET StudentsCount = (SELECT COUNT(*) FROM Students WHERE Students.CourseID_1 = Courses.CourseID OR Students.CourseID_2 = Courses.CourseID OR Students.CourseID_3 = Courses.CourseID OR Students.CourseID_4 = Courses.CourseID)')

    # Commit the changes and close the connection
    conn.commit()



def Generate_DB(N):
    # Connect to the SQLite database
    conn = sqlite3.connect('university.db')
    cursor = conn.cursor()

    # Create the Contact table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS Contact (
            ID INTEGER PRIMARY KEY,
            FirstName TEXT,
            LastName TEXT,
            Address TEXT,
            Email TEXT UNIQUE,
            Phone TEXT UNIQUE,
            Status TEXT,
            FieldOfStudy TEXT
        )
    ''')

    # Create the Students table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS Students (
            ID INTEGER PRIMARY KEY,
            FirstName TEXT,
            LastName TEXT,
            GPA REAL CHECK (GPA >= 60 AND GPA <= 100),
            PaymentStatus TEXT,
            FieldOfStudy TEXT,
            CourseID_1 TEXT,
            CourseID_2 TEXT,
            CourseID_3  TEXT,
            CourseID_4  TEXT,
            FOREIGN KEY (ID) REFERENCES Contact(ID)
        )
    ''')

    # Create the lecturers table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS lecturers (
            ID INTEGER PRIMARY KEY,
            FirstName TEXT,
            LastName TEXT,
            FieldOfStudy TEXT,
            CourseID_1  TEXT,
            CourseID_2  TEXT,
            FOREIGN KEY (ID) REFERENCES Contact(ID)
        )
    ''')

    # Create the Courses table
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS Courses (
            CourseID INTEGER PRIMARY KEY,
            CourseName TEXT
        )
    ''')

    # Generate sample data using Faker
    fake = Faker()

    cursor.execute('SELECT Email FROM Contact')
    existing_phones = {row[0] for row in cursor.fetchall()}

     # Fetch existing emails from the database
    cursor.execute('SELECT Email FROM Contact')
    existing_emails = {row[0] for row in cursor.fetchall()}

    # Populate the Contact table with sample data
    for _ in range(N):
        first_name, last_name = fake.first_name(), fake.last_name()
        address = fake.address()

        email = generate_unique_email(existing_emails, fake)
        phone = generate_unique_phones(existing_phones, fake)
        status = fake.random_element(['worker', 'student', 'student', 'student',  'student', 'lecturer', 'lecturer'])
        field_of_study = fake.random_element(['Math', 'Computer Science', 'Psychology'])
        cursor.execute('INSERT INTO Contact (FirstName, LastName, Address, Email, Phone, Status, FieldOfStudy) VALUES (?, ?, ?, ?, ?, ?, ?)',
                      (first_name, last_name, address, email, phone, status, field_of_study))
    conn.commit()




    # Populate the Courses table with sample data
    cursor.execute('SELECT COUNT(*) FROM Contact WHERE Status = "lecturer"')
    num_of_Courses = cursor.fetchone()[0]*2

    for _ in range(num_of_Courses):
        course_name = fake.catch_phrase()
        cursor.execute('INSERT INTO Courses (CourseName) VALUES (?)', (course_name,))

    conn.commit()


    # Iterate over the Contact table and insert all the students into the Students table
    cursor.execute('SELECT ID, FirstName, LastName, FieldOfStudy FROM Contact WHERE Status IS "student"')
    students = cursor.fetchall()


    for student in students:
        contact_id, first_name, last_name, field_of_study = student

        # Fetch three random CourseIDs from the Courses table
        cursor.execute('SELECT CourseID FROM Courses ORDER BY RANDOM() LIMIT 4')
        course_ids = [row[0] for row in cursor.fetchall()]
        course_id_1, course_id_2, course_id_3, course_id_4 = course_ids

        mean, std_dev = 80, 10
        gpa = np.round(np.clip(np.random.normal(mean, std_dev), 60, 100), 3)
        payment_status = fake.random_element(elements=('Paid', 'Unpaid'))

        cursor.execute('INSERT INTO Students (ID, FirstName, LastName, GPA, PaymentStatus, FieldOfStudy, CourseID_1, CourseID_2, CourseID_3, CourseID_4) '
                        'VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)', (contact_id, first_name, last_name, gpa, payment_status,
                                                            field_of_study, course_id_1, course_id_2, course_id_3, course_id_4))
        conn.commit()

    cursor.execute('SELECT ID, FirstName, LastName, FieldOfStudy FROM Contact WHERE Status IS "lecturer"')
    lecturers_data = cursor.fetchall()
    generate_lecturers(conn, lecturers_data)
    update_course_students_count(conn)
    conn.close()

def generate_lecturers(conn, lecturers_data):

    cursor = conn.cursor()
    # Get all the CourseIDs from the Courses table
    cursor.execute('SELECT CourseID FROM Courses')
    course_ids = cursor.fetchall()
    np.random.shuffle(course_ids)
    i = 0
    for lecturer in lecturers_data:
        contact_id, first_name, last_name, field_of_study = lecturer

        # Fetch three two CourseIDs from the Courses table
        cursor.execute('SELECT CourseID FROM Courses ORDER BY RANDOM() LIMIT 2')
        course_id_1, course_id_2 = course_ids[i][0], course_ids[i+1][0]
        i += 2
        cursor.execute('INSERT INTO lecturers (ID, FirstName, LastName, FieldOfStudy, CourseID_1, CourseID_2) '
                        'VALUES (?, ?, ?, ?, ?, ?)', (contact_id, first_name, last_name,
                                                            field_of_study, course_id_1, course_id_2))
    conn.commit()
    # Commit the changes and close the connection

# %%
def delete_db():
  db_file = '/content/university.db'
  os.remove(db_file)

def get_table_data():
    conn = sqlite3.connect('university.db')
    cursor = conn.cursor()

    cursor.execute("SELECT name FROM sqlite_master WHERE type='table'")
    tables = cursor.fetchall()

    data = {}
    for table in tables:
        table_name = table[0]
        cursor.execute(f"SELECT * FROM {table_name}")
        table_data = cursor.fetchall()

        # Create a PrettyTable instance and set the column names
        table_output = PrettyTable()
        cursor.execute(f"PRAGMA table_info({table_name})")
        columns = cursor.fetchall()
        column_names = [column[1] for column in columns]
        table_output.field_names = column_names

        # Add the data rows to the table
        for row in table_data:
            table_output.add_row(row)

        data[table_name] = table_output.get_string()

    conn.close()
    # Get and print the table data
    for table_name, table_data in data.items():
        print(f"Table: {table_name}")
        print(table_data)
        print()

def get_data_by_id(id):
    print('\n',' - *'*5)
    print(f'extract data for ID num: {id}:')
    conn = sqlite3.connect('university.db')
    cursor = conn.cursor()

    cursor.execute(f"SELECT * FROM Contact WHERE ID=?", (id,))
    contact_data = cursor.fetchall()

    cursor.execute(f"SELECT * FROM Students WHERE ID=?", (id,))
    student_data = cursor.fetchall()

    cursor.execute(f"SELECT * FROM lecturers WHERE ID=?", (id,))
    lecture_data = cursor.fetchall()

    conn.close()
    return contact_data, student_data, lecture_data


def get_data_by_name(name):
    print('\n',' - *'*5)
    print(f'extract data for the name: {name}:')
    conn = sqlite3.connect('university.db')
    cursor = conn.cursor()

    cursor.execute(f"SELECT * FROM Contact WHERE FirstName=? OR LastName=?", (name, name))
    contact_data = cursor.fetchall()

    cursor.execute("SELECT * FROM Students WHERE ID IN (SELECT ID FROM Contact WHERE FirstName = ? OR LastName = ?)", (name, name))
    student_data = cursor.fetchall()

    cursor.execute(f"SELECT * FROM lecturers WHERE ID=(SELECT ID FROM Contact WHERE FirstName=? OR LastName=?)", (name,name))

    lecture_data = cursor.fetchall()

    conn.close()
    return contact_data, student_data, lecture_data


def print_data(data):
    if any(data):
      for i, table in enumerate(data):
        print('\n',['Contact', 'Students','lecturers'][i], 'Table:')
        if table:
          print(table)
        else:
            print("No data found for the given name.")
    else:
      print('No data found for the given name')

def generate_unique_phones(existing_phones, fake):
    while True:
        phone = f'+972 {fake.msisdn()[5:]}'
        if phone not in existing_phones:
            return phone

def generate_unique_email(existing_emails, fake):
    while True:
        email = fake.email().rsplit('@', 1)[0] + '@ariel.ac.il'
        if email not in existing_emails:
            return email

def generate_people(name=None, N=1, status=None):
    conn = sqlite3.connect('university.db')

    cursor = conn.cursor()

    cursor.execute("SELECT MAX(ID) FROM Contact")
    last_id = cursor.fetchone()[0]

    cursor.execute('SELECT Email FROM Contact')
    existing_phones = {row[0] for row in cursor.fetchall()}

     # Fetch existing emails from the database
    cursor.execute('SELECT Email FROM Contact')
    existing_emails = {row[0] for row in cursor.fetchall()}

    for _ in range(N):
        if status == None:
           temp_status = fake.random_element(['worker', 'student', 'student', 'student',  'student', 'lecturer', 'lecturer'])
        else:
          temp_status = status
        last_id +=1
        first_name, last_name = fake.first_name(), fake.last_name()
        if name is not None:
            N = 1
            first_name = name
        address = fake.address()
        email =  generate_unique_email(existing_emails, fake)
        phone = generate_unique_phones(existing_phones, fake)
        field_of_study = fake.random_element(['Math', 'Computer Science', 'Psychology'])

        cursor.execute('INSERT INTO Contact (ID, FirstName, LastName, Address, Email, Phone, Status, FieldOfStudy) VALUES (?, ?, ?, ?, ?, ?, ?, ?)',
                  (last_id, first_name, last_name, address, email, phone, temp_status, field_of_study))
        conn.commit()


        if temp_status == 'student':
            cursor.execute('SELECT CourseID FROM Courses ORDER BY RANDOM() LIMIT 4')
            course_ids = [row[0] for row in cursor.fetchall()]
            course_ids += [None] * (4 - len(course_ids))
            course_id_1, course_id_2, course_id_3, course_id_4 = course_ids

            mean, std_dev = 80, 10
            gpa = np.round(np.clip(np.random.normal(mean, std_dev), 60, 100), 3)
            payment_status = fake.random_element(elements=('Paid', 'Unpaid'))

            cursor.execute('INSERT INTO Students (ID, FirstName, LastName, GPA, PaymentStatus, FieldOfStudy, CourseID_1, CourseID_2, CourseID_3, CourseID_4) '
                        'VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?)', (last_id, first_name, last_name, gpa, payment_status,
                                                            field_of_study, course_id_1, course_id_2, course_id_3, course_id_4))
        elif temp_status == 'lecturer':
              num_of_Courses =  2
              for _ in range(num_of_Courses):
                  course_name = fake.catch_phrase()
                  cursor.execute('INSERT INTO Courses (CourseName) VALUES (?)', (course_name,))

              lecturers_data = [(last_id, first_name, last_name, field_of_study)]
              generate_lecturers(conn, lecturers_data)

        conn.commit()
    print('\n', '- *'*5)
    if N == 1:
      print(f'{name} has been generated')
    else:
         print(f'{N} people have been generated')

    update_course_students_count(conn)
    conn.close()

# %% [markdown]
# #show off

# %%
#delete_db()

# %%
N = 10
Generate_DB(N)
get_table_data()
# Out:
# Table: Contact
# +----+-------------+----------+---------------------------------+--------------------------+---------------+----------+------------------+
# | ID |  FirstName  | LastName |             Address             |          Email           |     Phone     |  Status  |   FieldOfStudy   |
# +----+-------------+----------+---------------------------------+--------------------------+---------------+----------+------------------+
# | 1  |    Angela   |  Conway  |   10963 Wood Squares Apt. 344   |   nguzman@ariel.ac.il    | +972 39920268 | student  |    Psychology    |
# |    |             |          |      Bradleyfort, FL 68064      |                          |               |          |                  |
# | 2  |     Roy     |  Kelley  |         033 Patton Mall         |   rjackson@ariel.ac.il   | +972 89124640 | student  |    Psychology    |
# |    |             |          |     Robinsonhaven, NH 42879     |                          |               |          |                  |
# | 3  | Christopher |  Jones   |         9330 Zoe Course         |   smorales@ariel.ac.il   | +972 53701911 | student  | Computer Science |
# |    |             |          |       Ronaldtown, OK 27578      |                          |               |          |                  |
# | 4  |    Keith    | Jimenez  |          457 Blair Burg         |   lhebert@ariel.ac.il    | +972 88598113 | lecturer | Computer Science |
# |    |             |          |       Sarahhaven, ID 63312      |                          |               |          |                  |
# | 5  |   Jessica   |  Morris  | 18324 Marquez Harbors Suite 395 | perryjustin@ariel.ac.il  | +972 19029648 | lecturer |    Psychology    |
# |    |             |          |      Molinaburgh, VT 10553      |                          |               |          |                  |
# | 6  |     Lisa    |  Bryant  |  7567 Bruce Extensions Apt. 238 |   ubenton@ariel.ac.il    | +972 31741982 | student  | Computer Science |
# |    |             |          |    West Madisonfurt, RI 10220   |                          |               |          |                  |
# | 7  |     Lori    |  Parker  | 80969 Sanders Viaduct Suite 549 |   iobrien@ariel.ac.il    | +972 95961233 | student  |    Psychology    |
# |    |             |          |     Jennifermouth, NM 61952     |                          |               |          |                  |
# | 8  |   Michael   |  Mckay   |  7074 Nancy Crescent Suite 486  |   dblevins@ariel.ac.il   | +972 59362953 |  worker  |       Math       |
# |    |             |          |      Marshalltown, WI 33893     |                          |               |          |                  |
# | 9  |     Lisa    |   Lee    |    71118 Lori Pass Suite 378    | rodneycortez@ariel.ac.il | +972 22624100 | student  |       Math       |
# |    |             |          |   South Moniquetown, AL 33227   |                          |               |          |                  |
# | 10 |    Debra    | Ramirez  |        0940 Foley Tunnel        |   brett04@ariel.ac.il    | +972 73846201 | student  |    Psychology    |
# |    |             |          |       Riveraview, DC 19253      |                          |               |          |                  |
# +----+-------------+----------+---------------------------------+--------------------------+---------------+----------+------------------+
#
# Table: Students
# +----+-------------+----------+--------+---------------+------------------+------------+------------+------------+------------+
# | ID |  FirstName  | LastName |  GPA   | PaymentStatus |   FieldOfStudy   | CourseID_1 | CourseID_2 | CourseID_3 | CourseID_4 |
# +----+-------------+----------+--------+---------------+------------------+------------+------------+------------+------------+
# | 1  |    Angela   |  Conway  | 98.175 |     Unpaid    |    Psychology    |     2      |     4      |     3      |     1      |
# | 2  |     Roy     |  Kelley  | 70.081 |     Unpaid    |    Psychology    |     1      |     2      |     3      |     4      |
# | 3  | Christopher |  Jones   | 93.309 |      Paid     | Computer Science |     1      |     4      |     2      |     3      |
# | 6  |     Lisa    |  Bryant  | 66.421 |      Paid     | Computer Science |     4      |     1      |     2      |     3      |
# | 7  |     Lori    |  Parker  | 77.646 |     Unpaid    |    Psychology    |     1      |     3      |     2      |     4      |
# | 9  |     Lisa    |   Lee    | 75.582 |      Paid     |       Math       |     3      |     2      |     4      |     1      |
# | 10 |    Debra    | Ramirez  | 97.168 |      Paid     |    Psychology    |     1      |     3      |     2      |     4      |
# +----+-------------+----------+--------+---------------+------------------+------------+------------+------------+------------+
#
# Table: lecturers
# +----+-----------+----------+------------------+------------+------------+
# | ID | FirstName | LastName |   FieldOfStudy   | CourseID_1 | CourseID_2 |
# +----+-----------+----------+------------------+------------+------------+
# | 4  |   Keith   | Jimenez  | Computer Science |     1      |     3      |
# | 5  |  Jessica  |  Morris  |    Psychology    |     4      |     2      |
# +----+-----------+----------+------------------+------------+------------+
#
# Table: Courses
# +----------+------------------------------------------+---------------+
# | CourseID |                CourseName                | StudentsCount |
# +----------+------------------------------------------+---------------+
# |    1     |    Visionary foreground knowledgebase    |       7       |
# |    2     | Multi-lateral bottom-line knowledge user |       7       |
# |    3     |   Future-proofed executive middleware    |       7       |
# |    4     |     Cross-group web-enabled intranet     |       7       |
# +----------+------------------------------------------+---------------+

# %%
name = "Robert"
print_data(get_data_by_name(name))
print_data(get_data_by_id(5))
name = "Roy"
print_data(get_data_by_name(name))
generate_people(name=name,N=1)
print_data(get_data_by_name(name))
generate_people(N=20)
generate_people(N=60, status='student' )
# Out:
#   - * - * - * - * - *
# extract data for the name: Robert:
# No data found for the given name
#
#   - * - * - * - * - *
# extract data for ID num: 5:
#
#  Contact Table:
# [(5, 'Jessica', 'Morris', '18324 Marquez Harbors Suite 395\nMolinaburgh, VT 10553', 'perryjustin@ariel.ac.il', '+972 19029648', 'lecturer', 'Psychology')]
#
#  Students Table:
# No data found for the given name.
#
#  lecturers Table:
# [(5, 'Jessica', 'Morris', 'Psychology', '4', '2')]
#
#   - * - * - * - * - *
# extract data for the name: Roy:
#
#  Contact Table:
# [(2, 'Roy', 'Kelley', '033 Patton Mall\nRobinsonhaven, NH 42879', 'rjackson@ariel.ac.il', '+972 89124640', 'student', 'Psychology')]
#
#  Students Table:
# [(2, 'Roy', 'Kelley', 70.081, 'Unpaid', 'Psychology', '1', '2', '3', '4')]
#
#  lecturers Table:
# No data found for the given name.
#
#  - *- *- *- *- *
# Roy has been generated
#
#   - * - * - * - * - *
# extract data for the name: Roy:
#
#  Contact Table:
# [(2, 'Roy', 'Kelley', '033 Patton Mall\nRobinsonhaven, NH 42879', 'rjackson@ariel.ac.il', '+972 89124640', 'student', 'Psychology'), (11, 'Roy', 'Horn', '1673 Kathryn Harbors\nJosephport, NC 03593', 'kelli42@ariel.ac.il', '+972 24277768', 'student', 'Math')]
#
#  Students Table:
# [(2, 'Roy', 'Kelley', 70.081, 'Unpaid', 'Psychology', '1', '2', '3', '4'), (11, 'Roy', 'Horn', 81.471, 'Unpaid', 'Math', '3', '1', '4', '2')]
#
#  lecturers Table:
# No data found for the given name.
#
#  - *- *- *- *- *
# 20 people have been generated
#
#  - *- *- *- *- *
# 60 people have been generated

# %%
get_table_data()
# Out:
# Table: Contact
# +----+-------------+------------+-------------------------------------+------------------------------+---------------+----------+------------------+
# | ID |  FirstName  |  LastName  |               Address               |            Email             |     Phone     |  Status  |   FieldOfStudy   |
# +----+-------------+------------+-------------------------------------+------------------------------+---------------+----------+------------------+
# | 1  |    Angela   |   Conway   |     10963 Wood Squares Apt. 344     |     nguzman@ariel.ac.il      | +972 39920268 | student  |    Psychology    |
# |    |             |            |        Bradleyfort, FL 68064        |                              |               |          |                  |
# | 2  |     Roy     |   Kelley   |           033 Patton Mall           |     rjackson@ariel.ac.il     | +972 89124640 | student  |    Psychology    |
# |    |             |            |       Robinsonhaven, NH 42879       |                              |               |          |                  |
# | 3  | Christopher |   Jones    |           9330 Zoe Course           |     smorales@ariel.ac.il     | +972 53701911 | student  | Computer Science |
# |    |             |            |         Ronaldtown, OK 27578        |                              |               |          |                  |
# | 4  |    Keith    |  Jimenez   |            457 Blair Burg           |     lhebert@ariel.ac.il      | +972 88598113 | lecturer | Computer Science |
# |    |             |            |         Sarahhaven, ID 63312        |                              |               |          |                  |
# | 5  |   Jessica   |   Morris   |   18324 Marquez Harbors Suite 395   |   perryjustin@ariel.ac.il    | +972 19029648 | lecturer |    Psychology    |
# |    |             |            |        Molinaburgh, VT 10553        |                              |               |          |                  |
# | 6  |     Lisa    |   Bryant   |    7567 Bruce Extensions Apt. 238   |     ubenton@ariel.ac.il      | +972 31741982 | student  | Computer Science |
# |    |             |            |      West Madisonfurt, RI 10220     |                              |               |          |                  |
# | 7  |     Lori    |   Parker   |   80969 Sanders Viaduct Suite 549   |     iobrien@ariel.ac.il      | +972 95961233 | student  |    Psychology    |
# |    |             |            |       Jennifermouth, NM 61952       |                              |               |          |                  |
# | 8  |   Michael   |   Mckay    |    7074 Nancy Crescent Suite 486    |     dblevins@ariel.ac.il     | +972 59362953 |  worker  |       Math       |
# |    |             |            |        Marshalltown, WI 33893       |                              |               |          |                  |
# | 9  |     Lisa    |    Lee     |      71118 Lori Pass Suite 378      |   rodneycortez@ariel.ac.il   | +972 22624100 | student  |       Math       |
# |    |             |            |     South Moniquetown, AL 33227     |                              |               |          |                  |
# | 10 |    Debra    |  Ramirez   |          0940 Foley Tunnel          |     brett04@ariel.ac.il      | +972 73846201 | student  |    Psychology    |
# |    |             |            |         Riveraview, DC 19253        |                              |               |          |                  |
# | 11 |     Roy     |    Horn    |         1673 Kathryn Harbors        |     kelli42@ariel.ac.il      | +972 24277768 | student  |       Math       |
# |    |             |            |         Josephport, NC 03593        |                              |               |          |                  |
# | 12 |    Jason    |   Norris   | 91846 Jennifer Expressway Suite 936 |     kromero@ariel.ac.il      | +972 35100030 | student  |    Psychology    |
# |    |             |            |         Leonhaven, IN 82031         |                              |               |          |                  |
# | 13 |   Michael   |    Lane    |             633 Troy Run            | thompsonmichele@ariel.ac.il  | +972 50380666 |  worker  | Computer Science |
# |    |             |            |        Mendozamouth, ME 96132       |                              |               |          |                  |
# | 14 |    Rodney   | Middleton  |             USCGC Evans             |     nknight@ariel.ac.il      | +972 17666530 | student  |    Psychology    |
# |    |             |            |             FPO AE 03436            |                              |               |          |                  |
# | 15 |  Christina  |   Nunez    |     1341 Patel Canyon Suite 127     |     shaun74@ariel.ac.il      | +972 30773213 | student  |       Math       |
# |    |             |            |          New Luis, VA 40479         |                              |               |          |                  |
# | 16 |    Tommy    |   Olson    |          50267 Myers Street         |    kaylawoods@ariel.ac.il    | +972 82620682 | student  |    Psychology    |
# |    |             |            |        Garciaburgh, KS 72319        |                              |               |          |                  |
# | 17 |   Annette   |    Tran    |           650 Johnson Pike          |       olee@ariel.ac.il       | +972 69773232 | lecturer |    Psychology    |
# |    |             |            |       Blackwellport, MO 33445       |                              |               |          |                  |
# | 18 |     Amy     |  Freeman   |     72057 Boone Flats Suite 214     |     renee99@ariel.ac.il      | +972 64989608 | student  |    Psychology    |
# |    |             |            |         Reyesshire, MP 73592        |                              |               |          |                  |
# | 19 |     Lisa    |   Parker   |          Unit 8980 Box 0087         |      evan12@ariel.ac.il      | +972 39997485 | lecturer |       Math       |
# |    |             |            |             DPO AP 71166            |                              |               |          |                  |
# | 20 |    Carlos   |   Farley   |      328 Keith Avenue Suite 087     |  herreraashley@ariel.ac.il   | +972 30762732 | student  |    Psychology    |
# |    |             |            |        Lake Steven, CA 12880        |                              |               |          |                  |
# | 21 |   Kimberly  |  Hampton   |      324 Shari Parkway Apt. 169     |  mccluregregory@ariel.ac.il  | +972 30017031 | student  |       Math       |
# |    |             |            |        Port Victor, ND 63659        |                              |               |          |                  |
# | 22 |     Lisa    |   Lynch    |           2561 Wise Alley           |  alexanderjohn@ariel.ac.il   | +972 09228161 | student  |       Math       |
# |    |             |            |          Deanton, IL 14106          |                              |               |          |                  |
# | 23 |   Matthew   |   Romero   |           0687 Carol Drive          |   christine99@ariel.ac.il    | +972 39166004 |  worker  |       Math       |
# |    |             |            |        Ashleyburgh, WY 92137        |                              |               |          |                  |
# | 24 |   Shannon   |   Hughes   |        09342 Alvarez Village        |  jacobskimberly@ariel.ac.il  | +972 28840871 | student  |       Math       |
# |    |             |            |        East Andrew, CA 80761        |                              |               |          |                  |
# | 25 | Christopher |   Watson   |    9254 Wagner Meadows Suite 657    |      xlopez@ariel.ac.il      | +972 84355512 | student  |       Math       |
# |    |             |            |       North Michael, MD 61968       |                              |               |          |                  |
# | 26 |    Brenda   |   Moore    |     0366 Wilcox Ranch Suite 722     |  moralesmelissa@ariel.ac.il  | +972 94217747 | student  |       Math       |
# |    |             |            |         Murrayfurt, CT 87592        |                              |               |          |                  |
# | 27 |  Stephanie  |    Hart    |          Unit 2303 Box 8766         |  medinakathleen@ariel.ac.il  | +972 12415457 | lecturer |       Math       |
# |    |             |            |             DPO AE 30760            |                              |               |          |                  |
# | 28 |    Anita    |    King    |       192 Megan Union Apt. 647      |   susanmcclain@ariel.ac.il   | +972 91591261 | student  |    Psychology    |
# |    |             |            |         Port Paul, AZ 52391         |                              |               |          |                  |
# | 29 |     Mark    |   Yoder    |     1135 Eric Causeway Apt. 520     |    kristen02@ariel.ac.il     | +972 39280693 | student  |    Psychology    |
# |    |             |            |        East Thomas, OR 35251        |                              |               |          |                  |
# | 30 |    Amanda   |   Kelley   |          Unit 0070 Box 0095         |   raymondkaren@ariel.ac.il   | +972 80261582 | student  |       Math       |
# |    |             |            |             DPO AA 25667            |                              |               |          |                  |
# | 31 |   Kenneth   |  Campbell  |          Unit 6623 Box 4630         |   boydjillian@ariel.ac.il    | +972 07560882 | lecturer |       Math       |
# |    |             |            |             DPO AA 79098            |                              |               |          |                  |
# | 32 |    Robert   |   Casey    |          0175 Allen Gateway         |     wanda68@ariel.ac.il      | +972 04892900 | student  |    Psychology    |
# |    |             |            |      West Kennethton, MO 70719      |                              |               |          |                  |
# | 33 |     Anna    |  Baldwin   |          PSC 5512, Box 2473         |   jasonpierce@ariel.ac.il    | +972 88214544 | student  |    Psychology    |
# |    |             |            |             APO AE 99569            |                              |               |          |                  |
# | 34 |     Anne    |   Green    |      619 Andrew Cove Suite 763      |     markhall@ariel.ac.il     | +972 97274500 | student  |    Psychology    |
# |    |             |            |         New Laura, MH 82899         |                              |               |          |                  |
# | 35 |   Timothy   | Valentine  |         51903 Lindsay Forges        |  hamiltondavid@ariel.ac.il   | +972 95111615 | student  | Computer Science |
# |    |             |            |     South Craigchester, VT 82541    |                              |               |          |                  |
# | 36 |     Mary    |  Bonilla   |       063 Craig Ramp Suite 318      |     amymayo@ariel.ac.il      | +972 46630852 | student  |       Math       |
# |    |             |            |       South Sarahton, VT 06421      |                              |               |          |                  |
# | 37 |  Alexander  |  Johnston  |       325 Holly Cove Suite 691      |       plee@ariel.ac.il       | +972 34437007 | student  | Computer Science |
# |    |             |            |    South Nicholasburgh, FL 69275    |                              |               |          |                  |
# | 38 |    David    |   Foster   |           990 Gabriel Cove          |     jared34@ariel.ac.il      | +972 67386504 | student  | Computer Science |
# |    |             |            |      West Petershire, NC 16814      |                              |               |          |                  |
# | 39 |   Brandon   |   Moore    |          164 Steven Plains          |      jane06@ariel.ac.il      | +972 27381650 | student  |    Psychology    |
# |    |             |            |        North Eugene, ID 97375       |                              |               |          |                  |
# | 40 |   Kristen   |  Johnson   |      1195 Jill Coves Suite 675      |    tracywhite@ariel.ac.il    | +972 92356684 | student  |       Math       |
# |    |             |            |        Port Gabriel, NC 79977       |                              |               |          |                  |
# | 41 |    Erika    |  Andrews   |             USNS Joseph             |  chelseanguyen@ariel.ac.il   | +972 45638084 | student  |       Math       |
# |    |             |            |             FPO AE 49643            |                              |               |          |                  |
# | 42 |   Zachary   | Rodriguez  |      396 Angela Plaza Apt. 804      | christinamullins@ariel.ac.il | +972 04815798 | student  |       Math       |
# |    |             |            |        Jeffreyview, SC 86683        |                              |               |          |                  |
# | 43 |   Kathryn   |  Williams  |     984 Schmidt Island Apt. 146     | elliottkathleen@ariel.ac.il  | +972 32512122 | student  |       Math       |
# |    |             |            |     Port Michaelville, OK 05076     |                              |               |          |                  |
# | 44 |   Patricia  |   Combs    |     645 Conley Causeway Apt. 120    |     nraymond@ariel.ac.il     | +972 09074955 | student  | Computer Science |
# |    |             |            |        South Paula, GU 24865        |                              |               |          |                  |
# | 45 |   Theodore  |  Williams  |      32970 Lopez Glen Apt. 669      |  harriskathleen@ariel.ac.il  | +972 21782962 | student  |       Math       |
# |    |             |            |        East Kristen, MN 54135       |                              |               |          |                  |
# | 46 |    Jason    |   Evans    |           2920 Nathan Run           |     csnyder@ariel.ac.il      | +972 04930422 | student  |    Psychology    |
# |    |             |            |      North Sandrastad, UT 65030     |                              |               |          |                  |
# | 47 |   Brandon   |  Goodman   |           577 Robert Ports          |      qyoung@ariel.ac.il      | +972 40631068 | student  | Computer Science |
# |    |             |            |       Port Marytown, WA 35622       |                              |               |          |                  |
# | 48 |    Jordan   |   Brown    |          Unit 6549 Box 7155         |    ugriffith@ariel.ac.il     | +972 71626448 | student  | Computer Science |
# |    |             |            |             DPO AA 98526            |                              |               |          |                  |
# | 49 |   Danielle  |   Gomez    |          6781 Glenn Meadow          | hernandezmatthew@ariel.ac.il | +972 30139002 | student  | Computer Science |
# |    |             |            |        Edwardstown, DC 68936        |                              |               |          |                  |
# | 50 |   Melissa   |  Williams  |  275 Cassandra Extension Suite 435  |   vegabrandon@ariel.ac.il    | +972 02665751 | student  |    Psychology    |
# |    |             |            |       Alexanderfurt, NV 02506       |                              |               |          |                  |
# | 51 |    Shelby   |  Schwartz  |    638 Patrick Mission Suite 996    |   mckenziepena@ariel.ac.il   | +972 91242727 | student  |    Psychology    |
# |    |             |            |         Powelltown, MD 96590        |                              |               |          |                  |
# | 52 |    Brian    |  Townsend  |             USNV Miller             |    sarmstrong@ariel.ac.il    | +972 40388781 | student  |    Psychology    |
# |    |             |            |             FPO AE 84526            |                              |               |          |                  |
# | 53 |   Victoria  | Richardson |           4670 Lori Garden          |  shermanmichael@ariel.ac.il  | +972 83709717 | student  | Computer Science |
# |    |             |            |       Martinezmouth, SD 91935       |                              |               |          |                  |
# | 54 |   Kathleen  |   Weber    |        34882 Elizabeth Plaza        |    shawnjones@ariel.ac.il    | +972 12948898 | student  |       Math       |
# |    |             |            |     North Justinville, WY 79493     |                              |               |          |                  |
# | 55 |     Jose    |   Chaney   |      5796 Maria Point Suite 876     |     sarah34@ariel.ac.il      | +972 30972367 | student  |    Psychology    |
# |    |             |            |        Kristineside, PR 23382       |                              |               |          |                  |
# | 56 |     Jose    |  Johnson   |        068 Lee View Apt. 957        |  patriciagordon@ariel.ac.il  | +972 53625894 | student  |    Psychology    |
# |    |             |            |          Johnstad, GA 64244         |                              |               |          |                  |
# | 57 |    Nicole   |  Mcgrath   |          624 Katherine Rue          |    brianclark@ariel.ac.il    | +972 55843538 | student  | Computer Science |
# |    |             |            |        North Susan, MI 32576        |                              |               |          |                  |
# | 58 |     Adam    |   Becker   |    40201 Hunter Prairie Suite 823   |    richard78@ariel.ac.il     | +972 50331865 | student  | Computer Science |
# |    |             |            |          Loriport, IL 39817         |                              |               |          |                  |
# | 59 |   Timothy   |   Sexton   |    51113 Marks Streets Suite 460    |  stevenalvarado@ariel.ac.il  | +972 45027498 | student  | Computer Science |
# |    |             |            |       West Teresaton, WI 62829      |                              |               |          |                  |
# | 60 |   Matthew   |    Kerr    |       77319 Beck Via Apt. 768       |    boydjeremy@ariel.ac.il    | +972 39290626 | student  |    Psychology    |
# |    |             |            |         Ashleyview, MN 31598        |                              |               |          |                  |
# | 61 |  Alexander  |  Gardner   |      1814 Lisa Gardens Apt. 360     |     sdelgado@ariel.ac.il     | +972 12504578 | student  |    Psychology    |
# |    |             |            |       West Jillland, AL 81515       |                              |               |          |                  |
# | 62 |   Jeremiah  |   Leach    |           792 Hughes Ramp           |      lisa85@ariel.ac.il      | +972 94588393 | student  |    Psychology    |
# |    |             |            |      Lake Melindastad, FM 36628     |                              |               |          |                  |
# | 63 |    Kelly    |   Potter   |        9408 Sharon Underpass        |   pollardruben@ariel.ac.il   | +972 71261429 | student  |    Psychology    |
# |    |             |            |        North Scott, OK 47606        |                              |               |          |                  |
# | 64 |     Tony    |   Brown    |          998 Jamie Terrace          |    tarawiley@ariel.ac.il     | +972 28066162 | student  |    Psychology    |
# |    |             |            |        Lake Justin, AK 58251        |                              |               |          |                  |
# | 65 |    Tyler    |   Parks    |         7336 Patricia Square        |    bryantalex@ariel.ac.il    | +972 62618733 | student  | Computer Science |
# |    |             |            |        Port Robert, AK 52223        |                              |               |          |                  |
# | 66 |    Julia    |  Morrison  |          Unit 2265 Box 0309         |      john89@ariel.ac.il      | +972 63288609 | student  |       Math       |
# |    |             |            |             DPO AE 49628            |                              |               |          |                  |
# | 67 |   Randall   |   Walker   |          6507 Hansen Garden         |      dawn72@ariel.ac.il      | +972 91240708 | student  |       Math       |
# |    |             |            |        West Jeffrey, NH 64459       |                              |               |          |                  |
# | 68 |   Katrina   |   George   |          7206 Barry Divide          |  thompsonjulie@ariel.ac.il   | +972 95458338 | student  |    Psychology    |
# |    |             |            |         New Paula, MN 23535         |                              |               |          |                  |
# | 69 |   Derrick   | Alexander  |   23137 Jennifer Village Suite 931  |    josephtate@ariel.ac.il    | +972 96663819 | student  | Computer Science |
# |    |             |            |       Lake Davidside, TX 76870      |                              |               |          |                  |
# | 70 |   Benjamin  |   Green    |      86271 Amy Island Suite 846     |     llozano@ariel.ac.il      | +972 49222089 | student  | Computer Science |
# |    |             |            |        East Patrick, SD 27777       |                              |               |          |                  |
# | 71 |    Holly    |  Carroll   |      527 Hopkins Loaf Apt. 006      |   fordvanessa@ariel.ac.il    | +972 08605097 | student  |       Math       |
# |    |             |            |        West Lauren, FM 75654        |                              |               |          |                  |
# | 72 |  Alexandra  |  Thompson  |          Unit 2824 Box 4285         |     gsantos@ariel.ac.il      | +972 84481077 | student  | Computer Science |
# |    |             |            |             DPO AE 55612            |                              |               |          |                  |
# | 73 |     Jeff    |  Carrillo  |          66100 Andrew Vista         |     sortega@ariel.ac.il      | +972 19988329 | student  | Computer Science |
# |    |             |            |        West Morgan, AS 51023        |                              |               |          |                  |
# | 74 |    Sandra   |  Goodman   |   42366 Warner Mountains Apt. 346   |   lauraestrada@ariel.ac.il   | +972 67608241 | student  |       Math       |
# |    |             |            |        North Xavier, NH 23324       |                              |               |          |                  |
# | 75 |    Tammy    |   Hayes    |    02053 Martin Passage Suite 485   |    davidbanks@ariel.ac.il    | +972 87326223 | student  | Computer Science |
# |    |             |            |        Port Donald, UT 28261        |                              |               |          |                  |
# | 76 |  Katherine  |  Johnson   |          18312 Moreno Place         |     monica69@ariel.ac.il     | +972 54067258 | student  | Computer Science |
# |    |             |            |         Tylerhaven, AZ 80987        |                              |               |          |                  |
# | 77 |    Amanda   |   Smith    |    4825 James Mountain Suite 157    |  collinmorrison@ariel.ac.il  | +972 32157471 | student  |       Math       |
# |    |             |            |        Carlsonfort, AR 44720        |                              |               |          |                  |
# | 78 |    Rachel   |   Dixon    |     92505 Anthony Light Apt. 569    |     rlittle@ariel.ac.il      | +972 32700241 | student  |    Psychology    |
# |    |             |            |      West Marychester, NM 18546     |                              |               |          |                  |
# | 79 |    Tyrone   |  Ferguson  |     32554 Moreno Pine Suite 049     |   burkeandrew@ariel.ac.il    | +972 25470630 | student  | Computer Science |
# |    |             |            |        North Robert, LA 40718       |                              |               |          |                  |
# | 80 |     Kyle    |   Pineda   |    53427 Monique Village Apt. 207   |   lorisweeney@ariel.ac.il    | +972 38174924 | student  | Computer Science |
# |    |             |            |         Port Jason, MO 82682        |                              |               |          |                  |
# | 81 |    Renee    |  Sanchez   |   742 Mclaughlin Landing Apt. 019   |     nhunter@ariel.ac.il      | +972 71502845 | student  | Computer Science |
# |    |             |            |        East Nicole, MN 85577        |                              |               |          |                  |
# | 82 |   Jonathan  |   Rogers   |         21564 Brown Turnpike        | kathrynpatterson@ariel.ac.il | +972 49291374 | student  |       Math       |
# |    |             |            |        West Patrick, NE 31408       |                              |               |          |                  |
# | 83 |     Lisa    |   Booker   |       147 Lewis Lakes Apt. 082      |   christine56@ariel.ac.il    | +972 89714093 | student  |       Math       |
# |    |             |            |       Lake Jennifer, AZ 12419       |                              |               |          |                  |
# | 84 |  Elizabeth  |    Horn    |         3417 Kathryn Passage        |   mariahjones@ariel.ac.il    | +972 46390168 | student  | Computer Science |
# |    |             |            |        Lake Zachary, PW 11013       |                              |               |          |                  |
# | 85 |   Katrina   |    Long    |            USS Middleton            |     ythomas@ariel.ac.il      | +972 98706183 | student  |       Math       |
# |    |             |            |             FPO AP 87537            |                              |               |          |                  |
# | 86 |    James    |    Day     |    32918 Gonzalez Trace Suite 092   |     ljackson@ariel.ac.il     | +972 49818908 | student  | Computer Science |
# |    |             |            |      West Matthewland, ID 41296     |                              |               |          |                  |
# | 87 |    Angela   |  Arellano  |          PSC 8247, Box 0417         |    jocelyn79@ariel.ac.il     | +972 64802881 | student  |    Psychology    |
# |    |             |            |             APO AA 11493            |                              |               |          |                  |
# | 88 |     Amy     |  Allison   |      24921 Nathan Loop Apt. 606     |  alexanderisaac@ariel.ac.il  | +972 43933654 | student  |       Math       |
# |    |             |            |       Jonathanhaven, LA 35941       |                              |               |          |                  |
# | 89 |    Sandra   | Dickerson  |     0742 Sherri Views Suite 102     |    leahjones@ariel.ac.il     | +972 79747962 | student  | Computer Science |
# |    |             |            |        Bishopville, MI 23519        |                              |               |          |                  |
# | 90 |    Edward   |   Thomas   |     29392 Cortez Courts Apt. 773    |    halekelly@ariel.ac.il     | +972 32347983 | student  |    Psychology    |
# |    |             |            |         Aarontown, MH 11632         |                              |               |          |                  |
# | 91 |    Daniel   |   Durham   |      550 Floyd Village Apt. 133     |   robertpatel@ariel.ac.il    | +972 77992630 | student  | Computer Science |
# |    |             |            |     Port Danielchester, VA 49372    |                              |               |          |                  |
# +----+-------------+------------+-------------------------------------+------------------------------+---------------+----------+------------------+
#
# Table: Students
# +----+-------------+------------+--------+---------------+------------------+------------+------------+------------+------------+
# | ID |  FirstName  |  LastName  |  GPA   | PaymentStatus |   FieldOfStudy   | CourseID_1 | CourseID_2 | CourseID_3 | CourseID_4 |
# +----+-------------+------------+--------+---------------+------------------+------------+------------+------------+------------+
# | 1  |    Angela   |   Conway   | 98.175 |     Unpaid    |    Psychology    |     2      |     4      |     3      |     1      |
# | 2  |     Roy     |   Kelley   | 70.081 |     Unpaid    |    Psychology    |     1      |     2      |     3      |     4      |
# | 3  | Christopher |   Jones    | 93.309 |      Paid     | Computer Science |     1      |     4      |     2      |     3      |
# | 6  |     Lisa    |   Bryant   | 66.421 |      Paid     | Computer Science |     4      |     1      |     2      |     3      |
# | 7  |     Lori    |   Parker   | 77.646 |     Unpaid    |    Psychology    |     1      |     3      |     2      |     4      |
# | 9  |     Lisa    |    Lee     | 75.582 |      Paid     |       Math       |     3      |     2      |     4      |     1      |
# | 10 |    Debra    |  Ramirez   | 97.168 |      Paid     |    Psychology    |     1      |     3      |     2      |     4      |
# | 11 |     Roy     |    Horn    | 81.471 |     Unpaid    |       Math       |     3      |     1      |     4      |     2      |
# | 12 |    Jason    |   Norris   | 81.314 |     Unpaid    |    Psychology    |     2      |     1      |     3      |     4      |
# | 14 |    Rodney   | Middleton  | 86.149 |     Unpaid    |    Psychology    |     2      |     3      |     1      |     4      |
# | 15 |  Christina  |   Nunez    | 84.673 |      Paid     |       Math       |     4      |     3      |     2      |     1      |
# | 16 |    Tommy    |   Olson    | 68.478 |     Unpaid    |    Psychology    |     2      |     3      |     1      |     4      |
# | 18 |     Amy     |  Freeman   | 68.624 |      Paid     |    Psychology    |     3      |     5      |     1      |     6      |
# | 20 |    Carlos   |   Farley   | 76.544 |      Paid     |    Psychology    |     7      |     5      |     4      |     1      |
# | 21 |   Kimberly  |  Hampton   | 73.404 |     Unpaid    |       Math       |     7      |     8      |     1      |     5      |
# | 22 |     Lisa    |   Lynch    | 71.384 |     Unpaid    |       Math       |     1      |     4      |     7      |     2      |
# | 24 |   Shannon   |   Hughes   | 88.363 |     Unpaid    |       Math       |     7      |     6      |     5      |     2      |
# | 25 | Christopher |   Watson   | 84.782 |      Paid     |       Math       |     6      |     2      |     5      |     7      |
# | 26 |    Brenda   |   Moore    | 71.773 |      Paid     |       Math       |     5      |     4      |     8      |     6      |
# | 28 |    Anita    |    King    | 79.238 |     Unpaid    |    Psychology    |     4      |     1      |     6      |     3      |
# | 29 |     Mark    |   Yoder    | 81.247 |      Paid     |    Psychology    |     3      |     9      |     4      |     8      |
# | 30 |    Amanda   |   Kelley   | 81.97  |     Unpaid    |       Math       |     6      |     9      |     4      |     8      |
# | 32 |    Robert   |   Casey    | 73.199 |      Paid     |    Psychology    |     1      |     5      |     12     |     8      |
# | 33 |     Anna    |  Baldwin   | 79.047 |     Unpaid    |    Psychology    |     1      |     3      |     9      |     8      |
# | 34 |     Anne    |   Green    | 72.252 |      Paid     |    Psychology    |     12     |     9      |     1      |     11     |
# | 35 |   Timothy   | Valentine  | 84.32  |     Unpaid    | Computer Science |     11     |     1      |     10     |     8      |
# | 36 |     Mary    |  Bonilla   | 79.141 |      Paid     |       Math       |     12     |     6      |     11     |     3      |
# | 37 |  Alexander  |  Johnston  | 84.881 |     Unpaid    | Computer Science |     8      |     11     |     10     |     3      |
# | 38 |    David    |   Foster   | 90.733 |     Unpaid    | Computer Science |     1      |     3      |     4      |     11     |
# | 39 |   Brandon   |   Moore    | 100.0  |     Unpaid    |    Psychology    |     5      |     7      |     12     |     1      |
# | 40 |   Kristen   |  Johnson   | 84.544 |      Paid     |       Math       |     8      |     9      |     4      |     7      |
# | 41 |    Erika    |  Andrews   | 99.225 |     Unpaid    |       Math       |     9      |     3      |     1      |     7      |
# | 42 |   Zachary   | Rodriguez  | 86.414 |      Paid     |       Math       |     9      |     3      |     8      |     1      |
# | 43 |   Kathryn   |  Williams  | 95.034 |      Paid     |       Math       |     2      |     8      |     4      |     6      |
# | 44 |   Patricia  |   Combs    | 76.737 |     Unpaid    | Computer Science |     5      |     2      |     4      |     11     |
# | 45 |   Theodore  |  Williams  | 77.876 |      Paid     |       Math       |     10     |     8      |     6      |     9      |
# | 46 |    Jason    |   Evans    | 66.926 |      Paid     |    Psychology    |     9      |     12     |     3      |     4      |
# | 47 |   Brandon   |  Goodman   | 80.306 |     Unpaid    | Computer Science |     8      |     9      |     12     |     1      |
# | 48 |    Jordan   |   Brown    | 89.487 |     Unpaid    | Computer Science |     6      |     3      |     8      |     10     |
# | 49 |   Danielle  |   Gomez    | 68.297 |      Paid     | Computer Science |     8      |     9      |     3      |     2      |
# | 50 |   Melissa   |  Williams  | 81.401 |     Unpaid    |    Psychology    |     4      |     9      |     12     |     1      |
# | 51 |    Shelby   |  Schwartz  |  60.0  |     Unpaid    |    Psychology    |     1      |     3      |     5      |     4      |
# | 52 |    Brian    |  Townsend  | 64.072 |     Unpaid    |    Psychology    |     4      |     2      |     5      |     3      |
# | 53 |   Victoria  | Richardson | 81.829 |     Unpaid    | Computer Science |     8      |     11     |     3      |     2      |
# | 54 |   Kathleen  |   Weber    | 83.805 |     Unpaid    |       Math       |     7      |     8      |     4      |     12     |
# | 55 |     Jose    |   Chaney   | 74.496 |      Paid     |    Psychology    |     3      |     7      |     2      |     8      |
# | 56 |     Jose    |  Johnson   | 91.744 |     Unpaid    |    Psychology    |     4      |     11     |     10     |     12     |
# | 57 |    Nicole   |  Mcgrath   | 70.697 |     Unpaid    | Computer Science |     10     |     6      |     4      |     3      |
# | 58 |     Adam    |   Becker   | 69.451 |     Unpaid    | Computer Science |     2      |     6      |     1      |     3      |
# | 59 |   Timothy   |   Sexton   | 79.395 |      Paid     | Computer Science |     10     |     11     |     2      |     3      |
# | 60 |   Matthew   |    Kerr    | 84.944 |      Paid     |    Psychology    |     2      |     8      |     11     |     1      |
# | 61 |  Alexander  |  Gardner   | 76.009 |     Unpaid    |    Psychology    |     2      |     5      |     4      |     6      |
# | 62 |   Jeremiah  |   Leach    | 86.972 |      Paid     |    Psychology    |     8      |     6      |     2      |     9      |
# | 63 |    Kelly    |   Potter   | 85.645 |     Unpaid    |    Psychology    |     9      |     3      |     11     |     5      |
# | 64 |     Tony    |   Brown    | 84.601 |      Paid     |    Psychology    |     8      |     2      |     1      |     12     |
# | 65 |    Tyler    |   Parks    | 86.576 |      Paid     | Computer Science |     9      |     10     |     1      |     8      |
# | 66 |    Julia    |  Morrison  | 89.716 |     Unpaid    |       Math       |     7      |     4      |     10     |     5      |
# | 67 |   Randall   |   Walker   | 99.678 |     Unpaid    |       Math       |     4      |     6      |     7      |     1      |
# | 68 |   Katrina   |   George   | 79.799 |     Unpaid    |    Psychology    |     11     |     6      |     9      |     2      |
# | 69 |   Derrick   | Alexander  | 100.0  |      Paid     | Computer Science |     8      |     12     |     4      |     10     |
# | 70 |   Benjamin  |   Green    | 73.175 |      Paid     | Computer Science |     1      |     11     |     12     |     8      |
# | 71 |    Holly    |  Carroll   | 92.487 |      Paid     |       Math       |     11     |     7      |     3      |     2      |
# | 72 |  Alexandra  |  Thompson  | 78.532 |      Paid     | Computer Science |     4      |     2      |     1      |     5      |
# | 73 |     Jeff    |  Carrillo  | 60.115 |     Unpaid    | Computer Science |     5      |     10     |     11     |     8      |
# | 74 |    Sandra   |  Goodman   | 83.477 |     Unpaid    |       Math       |     7      |     12     |     4      |     3      |
# | 75 |    Tammy    |   Hayes    | 86.092 |      Paid     | Computer Science |     10     |     8      |     4      |     9      |
# | 76 |  Katherine  |  Johnson   | 75.97  |     Unpaid    | Computer Science |     7      |     10     |     6      |     3      |
# | 77 |    Amanda   |   Smith    | 82.045 |     Unpaid    |       Math       |     7      |     9      |     11     |     1      |
# | 78 |    Rachel   |   Dixon    | 74.082 |     Unpaid    |    Psychology    |     8      |     3      |     5      |     11     |
# | 79 |    Tyrone   |  Ferguson  | 75.517 |     Unpaid    | Computer Science |     4      |     6      |     11     |     5      |
# | 80 |     Kyle    |   Pineda   | 70.491 |     Unpaid    | Computer Science |     2      |     3      |     12     |     6      |
# | 81 |    Renee    |  Sanchez   | 89.662 |     Unpaid    | Computer Science |     8      |     2      |     11     |     10     |
# | 82 |   Jonathan  |   Rogers   | 98.667 |      Paid     |       Math       |     7      |     11     |     5      |     10     |
# | 83 |     Lisa    |   Booker   | 81.495 |      Paid     |       Math       |     2      |     9      |     11     |     3      |
# | 84 |  Elizabeth  |    Horn    | 91.733 |     Unpaid    | Computer Science |     1      |     12     |     9      |     10     |
# | 85 |   Katrina   |    Long    | 78.671 |     Unpaid    |       Math       |     7      |     12     |     8      |     11     |
# | 86 |    James    |    Day     | 90.949 |     Unpaid    | Computer Science |     12     |     4      |     9      |     1      |
# | 87 |    Angela   |  Arellano  | 92.166 |     Unpaid    |    Psychology    |     4      |     11     |     1      |     7      |
# | 88 |     Amy     |  Allison   | 73.38  |      Paid     |       Math       |     7      |     11     |     8      |     3      |
# | 89 |    Sandra   | Dickerson  | 78.671 |      Paid     | Computer Science |     10     |     7      |     9      |     5      |
# | 90 |    Edward   |   Thomas   | 75.01  |     Unpaid    |    Psychology    |     7      |     11     |     6      |     12     |
# | 91 |    Daniel   |   Durham   | 71.287 |     Unpaid    | Computer Science |     5      |     6      |     4      |     8      |
# +----+-------------+------------+--------+---------------+------------------+------------+------------+------------+------------+
#
# Table: lecturers
# +----+-----------+----------+------------------+------------+------------+
# | ID | FirstName | LastName |   FieldOfStudy   | CourseID_1 | CourseID_2 |
# +----+-----------+----------+------------------+------------+------------+
# | 4  |   Keith   | Jimenez  | Computer Science |     1      |     3      |
# | 5  |  Jessica  |  Morris  |    Psychology    |     4      |     2      |
# | 17 |  Annette  |   Tran   |    Psychology    |     3      |     5      |
# | 19 |    Lisa   |  Parker  |       Math       |     7      |     8      |
# | 27 | Stephanie |   Hart   |       Math       |     1      |     6      |
# | 31 |  Kenneth  | Campbell |       Math       |     3      |     6      |
# +----+-----------+----------+------------------+------------+------------+
#
# Table: Courses
# +----------+------------------------------------------+---------------+
# | CourseID |                CourseName                | StudentsCount |
# +----------+------------------------------------------+---------------+
# |    1     |    Visionary foreground knowledgebase    |       39      |
# |    2     | Multi-lateral bottom-line knowledge user |       33      |
# |    3     |   Future-proofed executive middleware    |       39      |
# |    4     |     Cross-group web-enabled intranet     |       40      |
# |    5     |     Advanced client-driven software      |       21      |
# |    6     |    Streamlined 3rdgeneration intranet    |       21      |
# |    7     |    Universal motivating architecture     |       22      |
# |    8     |  Multi-layered disintermediate forecast  |       31      |
# |    9     |      Switchable impactful framework      |       22      |
# |    10    |      Virtual composite architecture      |       17      |
# |    11    |      Cloned incremental definition       |       25      |
# |    12    |      Ameliorated holistic protocol       |       18      |
# +----------+------------------------------------------+---------------+
